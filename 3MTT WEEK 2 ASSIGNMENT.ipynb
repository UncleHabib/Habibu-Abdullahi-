# %% [markdown]
# #3 STATES IN NIGERIA WITH HIGHEST POPULATION

# %%
#Creating a datasets of 3 states

# %%
#Starting with Kano first
Highest=('Kano')

# %%
#Writing down Lagos as second
Second=("Lagos")

# %%
#Writing the last in the 3 STATES
Third=("Kaduna")

# %%
#creating a list
States = ['Kano, Lagos, Kaduna']
print(States)
# Out:
# ['Kano, Lagos, Kaduna']
