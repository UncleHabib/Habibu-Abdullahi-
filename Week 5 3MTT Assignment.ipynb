# %% [markdown]
# # Title: Week 5 3MTT Assignment
# # Course: Data Analysis and Vizualization
# # Question: Use pandas to clean and preprocess a messy dataset, documenting the steps taken during the cleaning process

# %% [markdown]
# # IMPORTING PANDAS LIBRARY

# %%
# Import pandas as pd
import pandas as pd

# %%
dataset = pd.read_csv("ST BATCH UPLOAD 1.csv")

# %%
dataset
# Out:
#      S/N                          Account Name  phone number  \
# 0    1.0  Tchoupki Kambir Mabrouka Abdoolkarim  8.122090e+09
# 1    2.0           MOUSA MOUBARAK MAHAMAN SANI  9.161288e+09
# 2    3.0                  GARBA MUHAMMAD AHMAD  8.102382e+09
# 3    4.0                IKECHUKWU NWANKWO JOHN  8.101325e+09
# 4    5.0                      IBRAHIM ABUBAKAR  8.133055e+09
# ..   ...                                   ...           ...
# 229  NaN                                   NaN           NaN
# 230  NaN                                   NaN           NaN
# 231  NaN                                   NaN           NaN
# 232  NaN                                   NaN           NaN
# 233  NaN                                   NaN           NaN
#
#                               ADDRESS          surname First  name  \
# 0                                TAKA  Tchoupki kambir   Mabrouka
# 1        BOURJA,MARADI NIGER REPUBLIC   MOUSA MOUBARAK    MAHAMAN
# ...

# %%
# Displaying a data frame from the dataset
df = pd.DataFrame(dataset)

# %%
print(df)
# Out:
#      S/N                          Account Name  phone number  \
# 0    1.0  Tchoupki Kambir Mabrouka Abdoolkarim  8.122090e+09
# 1    2.0           MOUSA MOUBARAK MAHAMAN SANI  9.161288e+09
# 2    3.0                  GARBA MUHAMMAD AHMAD  8.102382e+09
# 3    4.0                IKECHUKWU NWANKWO JOHN  8.101325e+09
# 4    5.0                      IBRAHIM ABUBAKAR  8.133055e+09
# ..   ...                                   ...           ...
# 229  NaN                                   NaN           NaN
# 230  NaN                                   NaN           NaN
# 231  NaN                                   NaN           NaN
# 232  NaN                                   NaN           NaN
# 233  NaN                                   NaN           NaN
#
#                               ADDRESS          surname First  name  \
# 0                                TAKA  Tchoupki kambir   Mabrouka
# 1        BOURJA,MARADI NIGER REPUBLIC   MOUSA MOUBARAK    MAHAMAN
# ...

# %% [markdown]
# # HANDLING THE PROBLEM

# %%
# Find the missing values using any
df.isnull().any()
# Out:
# S/N                    True
# Account Name           True
# phone number           True
# ADDRESS                True
# surname                True
# First  name            True
# Other Names            True
# DOB                    True
# GENDER                 True
# registration number    True
# DEPARTMENT             True
# Unnamed: 11            True
# Unnamed: 12            True
# Unnamed: 13            True
# Unnamed: 14            True
# dtype: bool

# %% [markdown]
# # DETECTING NaN VALUES

# %%
# Finding th missing values
missing_value = ["NaN","na","N/a","Null"]
dataset = pd.read_csv("ST BATCH UPLOAD 1.csv", na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# S/N                    127
# Account Name           127
# phone number           127
# ADDRESS                127
# surname                127
# First  name            127
# Other Names            157
# DOB                    127
# GENDER                 127
# registration number    127
# DEPARTMENT             127
# Unnamed: 11            234
# Unnamed: 12            234
# Unnamed: 13            234
# Unnamed: 14            234
# dtype: int64

# %%
# Removing the values
df
# Out:
#      S/N                          Account Name  phone number  \
# 0    1.0  Tchoupki Kambir Mabrouka Abdoolkarim  8.122090e+09
# 1    2.0           MOUSA MOUBARAK MAHAMAN SANI  9.161288e+09
# 2    3.0                  GARBA MUHAMMAD AHMAD  8.102382e+09
# 3    4.0                IKECHUKWU NWANKWO JOHN  8.101325e+09
# 4    5.0                      IBRAHIM ABUBAKAR  8.133055e+09
# ..   ...                                   ...           ...
# 229  NaN                                   NaN           NaN
# 230  NaN                                   NaN           NaN
# 231  NaN                                   NaN           NaN
# 232  NaN                                   NaN           NaN
# 233  NaN                                   NaN           NaN
#
#                               ADDRESS          surname First  name  \
# 0                                TAKA  Tchoupki kambir   Mabrouka
# 1        BOURJA,MARADI NIGER REPUBLIC   MOUSA MOUBARAK    MAHAMAN
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [S/N, Account Name, phone number, ADDRESS, surname, First  name, Other Names, DOB, GENDER, registration number, DEPARTMENT, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14]
# Index: []

# %%
df.dropna(how='all')
# Out:
#        S/N                          Account Name  phone number  \
# 0      1.0  Tchoupki Kambir Mabrouka Abdoolkarim  8.122090e+09
# 1      2.0           MOUSA MOUBARAK MAHAMAN SANI  9.161288e+09
# 2      3.0                  GARBA MUHAMMAD AHMAD  8.102382e+09
# 3      4.0                IKECHUKWU NWANKWO JOHN  8.101325e+09
# 4      5.0                      IBRAHIM ABUBAKAR  8.133055e+09
# ..     ...                                   ...           ...
# 102  103.0                     MUSTAPHA ABUBAKAR  9.078180e+09
# 103  104.0                   LAMIDO HABIBA USMAN  9.071518e+09
# 104  105.0                 MUSTAPHA TIJANI YUSUF  9.169315e+09
# 105  106.0              SULEIMAN SULEIMAN SHARIF  8.100039e+09
# 106  107.0                 MAHMUD ABDALLAH SADIQ  9.133433e+09
#
#                                           ADDRESS          surname  \
# 0                                            TAKA  Tchoupki kambir
# 1                    BOURJA,MARADI NIGER REPUBLIC   MOUSA MOUBARAK
# ...
